# %% [markdown]
# # Proyek Pertama: Menyelesaikan Permasalahan Human Resource

# %% [markdown]
# - Nama: Agus Wahyudi
# - Email: wahyoediagoes13@gmail.com
# - Id Dicoding: audi1308

# %% [markdown]
# ## Import Library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sqlalchemy import create_engine

# %% [markdown]
# ## Data Understanding

# %%
# importing dataset
df = pd.read_csv('employee_data.csv', index_col='EmployeeId')
df.head()
# Out:
#             Age  Attrition     BusinessTravel  DailyRate  \
# EmployeeId
# 1            38        NaN  Travel_Frequently       1444
# 2            37        1.0      Travel_Rarely       1141
# 3            51        1.0      Travel_Rarely       1323
# 4            42        0.0  Travel_Frequently        555
# 5            40        NaN      Travel_Rarely       1194
#
#                         Department  DistanceFromHome  Education  \
# EmployeeId
# 1                  Human Resources                 1          4
# 2           Research & Development                11          2
# 3           Research & Development                 4          4
# 4                            Sales                26          3
# 5           Research & Development                 2          4
#
#            EducationField  EmployeeCount  EnvironmentSatisfaction  ...  \
# EmployeeId                                                         ...
# 1                   Other              1                        4  ...
# 2                 Medical              1                        1  ...
# 3           Life Sciences              1                        1  ...
# 4               Marketing              1                        3  ...
# 5                 Medical              1                        3  ...
#
#            RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# EmployeeId
# 1                                 2             80                 1
# 2                                 1             80                 0
# 3                                 3             80                 3
# 4                                 4             80                 1
# 5                                 2             80                 3
#
#             TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  \
# EmployeeId
# 1                           7                     2                3
# 2                          15                     2                1
# 3                          18                     2                4
# 4                          23                     2                4
# 5                          20                     2                3
#
#            YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# EmployeeId
# 1                       6                   2                        1
# 2                       1                   0                        0
# 3                      10                   0                        2
# 4                      20                   4                        4
# 5                       5                   3                        0
#
#             YearsWithCurrManager
# EmployeeId
# 1                              2
# 2                              0
# 3                              7
# 4                              8
# 5                              2
#
# [5 rows x 34 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1470 entries, 1 to 1470
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1058 non-null   float64
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EnvironmentSatisfaction   1470 non-null   int64
#  10  Gender                    1470 non-null   object
#  11  HourlyRate                1470 non-null   int64
#  12  JobInvolvement            1470 non-null   int64
#  13  JobLevel                  1470 non-null   int64
#  14  JobRole                   1470 non-null   object
#  15  JobSatisfaction           1470 non-null   int64
#  16  MaritalStatus             1470 non-null   object
#  17  MonthlyIncome             1470 non-null   int64
#  18  MonthlyRate               1470 non-null   int64
#  19  NumCompaniesWorked        1470 non-null   int64
#  20  Over18                    1470 non-null   object
#  21  OverTime                  1470 non-null   object
#  22  PercentSalaryHike         1470 non-null   int64
#  23  PerformanceRating         1470 non-null   int64
#  24  RelationshipSatisfaction  1470 non-null   int64
#  25  StandardHours             1470 non-null   int64
#  26  StockOptionLevel          1470 non-null   int64
#  27  TotalWorkingYears         1470 non-null   int64
#  28  TrainingTimesLastYear     1470 non-null   int64
#  29  WorkLifeBalance           1470 non-null   int64
#  30  YearsAtCompany            1470 non-null   int64
#  31  YearsInCurrentRole        1470 non-null   int64
#  32  YearsSinceLastPromotion   1470 non-null   int64
#  33  YearsWithCurrManager      1470 non-null   int64
# dtypes: float64(1), int64(25), object(8)
# memory usage: 402.0+ KB

# %%
df.describe()
# Out:
#                Age    Attrition    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1058.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810     0.169187   802.485714          9.192517     2.912925
# std       9.135373     0.375094   403.509100          8.106864     1.024165
# min      18.000000     0.000000   102.000000          1.000000     1.000000
# 25%      30.000000     0.000000   465.000000          2.000000     2.000000
# 50%      36.000000     0.000000   802.000000          7.000000     3.000000
# 75%      43.000000     0.000000  1157.000000         14.000000     4.000000
# max      60.000000     1.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count         1470.0              1470.000000  1470.000000     1470.000000
# mean             1.0                 2.721769    65.891156        2.729932
# std              0.0                 1.093082    20.329428        0.711561
# min              1.0                 1.000000    30.000000        1.000000
# 25%              1.0                 2.000000    48.000000        2.000000
# 50%              1.0                 3.000000    66.000000        3.000000
# 75%              1.0                 4.000000    83.750000        3.000000
# max              1.0                 4.000000   100.000000        4.000000
#
#           JobLevel  ...  RelationshipSatisfaction  StandardHours  \
# count  1470.000000  ...               1470.000000         1470.0
# mean      2.063946  ...                  2.712245           80.0
# std       1.106940  ...                  1.081209            0.0
# min       1.000000  ...                  1.000000           80.0
# 25%       1.000000  ...                  2.000000           80.0
# 50%       2.000000  ...                  3.000000           80.0
# 75%       3.000000  ...                  4.000000           80.0
# max       5.000000  ...                  4.000000           80.0
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count       1470.000000        1470.000000            1470.000000
# mean           0.793878          11.279592               2.799320
# std            0.852077           7.780782               1.289271
# min            0.000000           0.000000               0.000000
# 25%            0.000000           6.000000               2.000000
# 50%            1.000000          10.000000               3.000000
# 75%            1.000000          15.000000               3.000000
# max            3.000000          40.000000               6.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      1470.000000     1470.000000         1470.000000
# mean          2.761224        7.008163            4.229252
# std           0.706476        6.126525            3.623137
# min           1.000000        0.000000            0.000000
# 25%           2.000000        3.000000            2.000000
# 50%           3.000000        5.000000            3.000000
# 75%           3.000000        9.000000            7.000000
# max           4.000000       40.000000           18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count              1470.000000           1470.000000
# mean                  2.187755              4.123129
# std                   3.222430              3.568136
# min                   0.000000              0.000000
# 25%                   0.000000              2.000000
# 50%                   1.000000              3.000000
# 75%                   3.000000              7.000000
# max                  15.000000             17.000000
#
# [8 rows x 26 columns]

# %%
df.hist(figsize=(10,10))
plt.tight_layout()

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Attrition                   412
# Age                           0
# StandardHours                 0
# NumCompaniesWorked            0
# Over18                        0
# OverTime                      0
# PercentSalaryHike             0
# PerformanceRating             0
# RelationshipSatisfaction      0
# StockOptionLevel              0
# TotalWorkingYears             0
# TrainingTimesLastYear         0
# WorkLifeBalance               0
# YearsAtCompany                0
# YearsInCurrentRole            0
# YearsSinceLastPromotion       0
# MonthlyRate                   0
# MonthlyIncome                 0
# MaritalStatus                 0
# JobSatisfaction               0
# JobRole                       0
# JobLevel                      0
# JobInvolvement                0
# HourlyRate                    0
# Gender                        0
# EnvironmentSatisfaction       0
# EmployeeCount                 0
# EducationField                0
# Education                     0
# DistanceFromHome              0
# Department                    0
# DailyRate                     0
# BusinessTravel                0
# YearsWithCurrManager          0
# dtype: int64

# %%
missing_percentage = df['Attrition'].isnull().mean() * 100
print(f"Percentage of missing values in 'Attrition': {missing_percentage:.2f}%")
# Out:
# Percentage of missing values in 'Attrition': 28.03%

# %% [markdown]
# Terdpat missing value pada kolom "Attrition" dan kolom ini merupakan yang penting untuk proses analisis dan karena tidak cukup informasi lain yang kuat dalam handling missing value ini jadi lebih baik untuk dihapus. Meskipun memiliki porsi 28% untuk valuenya tapi cara ini lebih baik daripada berimpact kebiasan pada data yang dihasilkan.

# %%
#menghapus data yang kosong dalam attrition
df.dropna(inplace = True)

# %%
# Check duplicate
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Attrition Distribution

# %%
sns.countplot(data = df, x = 'Attrition').set_title('Attrition Distribution')
# Out:
# Text(0.5, 1.0, 'Attrition Distribution')

# %% [markdown]
# Berdasarkan grafik bar chart, mayoritas karyawan memilih untuk tidak keluar dari perusahaan. Namun dari sisi pengembangan model machine learning, data ini imbalanced dan perlu dilakukan hadnling seperti oversampling agar hasil klasifikasi karyawan menjadi tidak overfitting.

# %% [markdown]
# ## Employee Personality

# %%
# mengubah value menjadi interval
def conv_to_interval(label):
    return f'{label.left} - {label.right}'

# mengubah data numerik menjadi kategorik
def conv_to_categorical(df,column,num):
    bins = np.linspace(0,df[column].max(),num=num).round()
    return pd.cut(df[column],bins = bins).apply(lambda x : conv_to_interval(x))

# %%
def show_segment_bar_chart(df,col_list,sup_title,figsize = (12,12)):
    row = (len(col_list) + 1)//2
    fig,axes = plt.subplots(row,2,figsize = figsize)

    for i in range(len(col_list)):
        col_name = col_list[i]
        cont_table = pd.crosstab(df['Attrition'],df[col_name])
        attrited_ps = (cont_table.loc[1]/cont_table.sum()).sort_values()

        ax = axes[i//2,i%2] if row > 1 else axes[i]

        max_idx = attrited_ps[attrited_ps == attrited_ps.max()].index
        color = ['orange' if idx == max_idx else 'gray' for idx in attrited_ps.index]

        attrited_ps.plot(kind = 'barh', xlabel = 'percentage',title = col_name,ax = ax, color = color)

    if len(col_list) < row * 2:
        for i in range(len(col_list), row * 2):
            fig.delaxes(axes[i // 2, i % 2])

    plt.suptitle(f'Attrition based on {sup_title}',y = 1)
    fig.tight_layout()

# %%
show_segment_bar_chart(df,['JobRole','JobLevel','MaritalStatus'],'Employee Personalities',figsize= (10,10))

# %% [markdown]
# Berdasarkan personal information karyawan, kebanyakan yang memilih untuk keluar dari perusahaan adalah :
# 1. masih single (belum menikah)
# 2. bekerja sebagai sales
# 3. memiliki tingkat jabatan rendah

# %% [markdown]
# ## Work Satisfaction

# %%
# mengubah data overtime menjadi boolean
df['OverTime'] = df['OverTime'].apply(lambda x : x == 'Yes')

# %%
fig,axes = plt.subplots(1,5,figsize = (10,5))
col_list = ['RelationshipSatisfaction','JobSatisfaction','EnvironmentSatisfaction','WorkLifeBalance','OverTime']

for i in range(len(col_list)):
    name_col = col_list[i]
    df[name_col].value_counts().plot(kind = 'pie', autopct = '%1.0f%%',ax = axes[i], title = name_col).set_ylabel('')

fig.tight_layout()

# %% [markdown]
# Mayoritas karyawan merasa senang bekerja dalam perusahaan ini. Hubungan dengan karyawan baik, lingkungan yang mendukung dan work life balance terjaga. Namun perlu disadari, jumlah karyawan yang tidak puas dalam hubungan, karir dan lingkungan kerja cukup besar (19%-20%). Selain dari kepuasan kerja, 29% karyawan sering bekerja lembur dan 19% karyawan sering mendapat perjalanan kerja.

# %%
show_segment_bar_chart(df,col_list,'Working Condition',figsize= (10,10))

# %% [markdown]
# Berdasarkan grafik bar chart, mayoritas karyawan keluar dari perusahaan karena mereka sering bekerja lembur, kehidupan karir serta lingkungan kerja yang tidak mendukung dan sering mendapat perjalanan kerja.

# %% [markdown]
# ## Salary

# %%
df['MonthlyRate'] = conv_to_categorical(df,'MonthlyRate',5)
df['HourlyRate'] = conv_to_categorical(df,'HourlyRate',5)
df['MonthlyIncome'] = conv_to_categorical(df,'MonthlyIncome',5)
df['PercentSalaryHike'] = conv_to_categorical(df,'PercentSalaryHike',5)

# %%
show_segment_bar_chart(df,['MonthlyRate','HourlyRate','MonthlyIncome','PercentSalaryHike'],'Salary',figsize= (12,6))

# %% [markdown]
# Berdasarkan bar chart, mayoritas karyawan yang keluar dari perusahaan memiliki gaji harian dan gaji bulanan yang tinggi.

# %% [markdown]
# ## Analisis Lanjutan

# %%
low_income = df.MonthlyIncome.unique()[0]

job_grouped_corr = df.groupby('JobRole').agg(
    job_level = ('JobLevel','median'),
    YearsAtCompany = ('YearsAtCompany','median'),
    low_monthly_income_ps= ('MonthlyIncome', lambda x: x.value_counts()[low_income]*100/len(x)),
    bad_relationship_ps = ('RelationshipSatisfaction',lambda x: x.value_counts()[1]*100/len(x)),
    bad_job_satisfaction_ps = ('JobSatisfaction',lambda x: x.value_counts()[1]*100/len(x)),
    bad_work_life_balance_ps = ('WorkLifeBalance',lambda x: x.value_counts()[1]*100/len(x)),
    bad_environment_ps = ('EnvironmentSatisfaction',lambda x: x.value_counts()[1]*100/len(x)),
    attrition_ps = ('Attrition',  lambda x: np.mean(x)*100),
    overtime_ps = ('OverTime',  lambda x : np.mean(x)*100),
)

job_grouped_corr.rename(
    {'job_level':'Job Level',
     'YearsAtCompany':'Years At Company',
     'low_monthly_income_ps': 'Low Monthly Income (%)',
     'bad_relationship_ps': 'Bad Relationship (%)',
     'bad_job_satisfaction_ps': 'Bad Job Satisfaction (%)',
     'bad_environment_ps': 'Bad Environment (%)',
     'bad_work_life_balance_ps': 'Bad Work Life Balance (%)',
     'attrition_ps':'Attrition (%)',
     'overtime_ps' : 'OverTime (%)'
     },
     axis = 1,
     inplace = 1
)

# %%
corr_attrition = job_grouped_corr.corr().sort_values(by = 'Attrition (%)',ascending= False)[['Attrition (%)']]
sns.heatmap(corr_attrition,annot = True).set_title('Attrition Percentage Correlation')
plt.xlabel('Correlation Coeficient')
plt.ylabel('Variables')
# Out:
# Text(50.7222222222222, 0.5, 'Variables')

# %% [markdown]
# Berdasarkan hasil analisa dengan korelasi Pearson, ada beberapa faktor yang berkorelasi dengan tingginya tingkat persentase karyawan keluar :
#
# 1. **Tingkat jabatan (Job Level)** memiliki korelasi negatif yang kuat dengan tingkat karyawan yang keluar (-0.72). Artinya, semakin tinggi jabatan seseorang, semakin rendah kemungkinan mereka keluar dari perusahaan.
#
# 2. **Tahun kerja karyawan (Years At Company)** juga memiliki korelasi negatif yang kuat dengan tingkat karyawan yang keluar (-0.76). Ini menunjukkan bahwa semakin lama seseorang bekerja di perusahaan, semakin rendah kemungkinan mereka untuk keluar.
#
# 3. **Pendapatan perbulan yang kecil (Low Monthly Income %)** memiliki korelasi positif yang kuat dengan tingkat karyawan yang keluar (0.85). Artinya, karyawan dengan pendapatan lebih rendah cenderung lebih mungkin untuk keluar dari perusahaan.

# %%
job_grouped_corr[['Attrition (%)','Years At Company','Low Monthly Income (%)','Job Level']].sort_values(by = 'Attrition (%)', ascending = False)
# Out:
#                            Attrition (%)  Years At Company  \
# JobRole
# Sales Representative           43.103448               2.0
# Laboratory Technician          26.063830               4.0
# Human Resources                20.000000               5.0
# Research Scientist             17.757009               4.0
# Sales Executive                16.810345               7.0
# Healthcare Representative       9.090909               7.0
# Manufacturing Director          6.542056               7.0
# Manager                         6.329114              14.0
# Research Director               3.225806               8.5
#
#                            Low Monthly Income (%)  Job Level
# JobRole
# Sales Representative                    98.275862        1.0
# Laboratory Technician                   89.893617        1.0
# Human Resources                         63.333333        1.0
# Research Scientist                      93.457944        1.0
# Sales Executive                         25.862069        2.0
# Healthcare Representative               15.909091        2.0
# Manufacturing Director                  21.495327        2.0
# Manager                                  0.000000        4.0
# Research Director                        0.000000        4.0

# %%
df.to_csv('data.csv', index=False)  # Set index=False to avoid writing row indices

# %% [markdown]
# Berdasarkan tabel, pekerjaan yang sesuai dengan hasil analisis ini adalah "Sales Represenative". Pekerjaan ini memiliki tingkat persentase karyawan yang keluar yang tinggi serta penghasilan perbulan yang cukup rendah. Kebanyakan karyawan dari bagian sales, baru bekerja rata - rata 2 tahun dan memiliki jabatan yang sangat rendah.

# %%
"""
# Export to SQL 
df_analysis = df[[
    'DailyRate',
    'MonthlyRate',
    'MonthlyIncome',
    'JobRole',
    'JobLevel',
    'OverTime',
    'RelationshipSatisfaction',
    'JobSatisfaction',
    'YearsAtCompany',
    'YearsSinceLastPromotion',
    'TrainingTimesLastYear',
    'EnvironmentSatisfaction',
    'WorkLifeBalance',
    'Attrition'
]]
"""

# %%
"""
# password database: jayajayaattrition111
engine = create_engine('postgresql://postgres.kvmrcvbcomzbcwqtnokh:jayajayaattrition111@aws-0-ap-southeast-1.pooler.supabase.com:5432/postgres')
df_analysis.to_sql('jayajaya_attrition',engine)
"""
# Out:
# "\n# password database: jayajayaattrition111\nengine = create_engine('postgresql://postgres.kvmrcvbcomzbcwqtnokh:jayajayaattrition111@aws-0-ap-southeast-1.pooler.supabase.com:5432/postgres')\ndf_analysis.to_sql('jayajaya_attrition',engine)\n"

# %%
"""
corr_attrition.to_sql('job_group_corr_1',engine)
"""
# Out:
# 9
